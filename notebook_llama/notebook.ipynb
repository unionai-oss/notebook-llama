# %%
from IPython.display import Audio
import IPython.display as ipd

# %%
import union as union
from union.remote import UnionRemote

remote = UnionRemote()
output = remote.get("flyte://v1/org/cosmicbboy/default/development/arz727jg2twn9zz7vsgh/n3/o")
podcast_file = output.get("o0", union.FlyteFile)
# Out:
# WARNING:root:Failed to refresh token. Kicking off a full authorization flow.
# 127.0.0.1 - - [22/Jan/2025 11:07:54] "GET /callback?code=k84XesdrG5lgdd6qHZh1XeodDappD4Q8Gu6BPwu20t4&state=5YGI4vt1DOm20WtgSk490yh2LOyZvMxceYL5lxO_jGzWZ4dvNI7a6A HTTP/1.1" 200 -

# %%
podcast_file.download()
audio = Audio(podcast_file.path)
ipd.display(audio)
# Out:
# WARNING:aiobotocore.credentials:Refreshing temporary credentials failed during mandatory refresh period.
# Traceback (most recent call last):
#   File "/Users/nielsbantilan/miniforge3/envs/notebook-llama/lib/python3.11/site-packages/aiobotocore/credentials.py", line 1039, in _get_credentials
#     response = await client.get_role_credentials(**kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nielsbantilan/miniforge3/envs/notebook-llama/lib/python3.11/site-packages/aiobotocore/client.py", line 412, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.UnauthorizedException: An error occurred (UnauthorizedException) when calling the GetRoleCredentials operation: Session token not found or invalid
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
with open("podcast.html", "w") as f:
    f.write(audio._repr_html_())
